# %%
import pandas as pd

# %%
df = pd.read_csv('neurolinguistics_study_version_2-merged.csv')

df.head()
# Out:
#    workerid proliferate.condition  correct_answer prime probeContent response  \
# 0        19            condition1               1     準            準        f
# 1        19            condition1               1     輸            輸        f
# 2        19            condition1               2     湧            敢        j
# 3        19            condition1               2     炸            查        j
# 4        19            condition1               1     繪            繪        f
#
#      rt  slide_number_in_experiment target trial_type  ...  \
# 0  2195                           8      腦        con  ...
# 1  2056                           9      贏    sem-sem  ...
# 2  1828                          10      敢   phon-sem  ...
# 3  1898                          11      查        con  ...
# 4  2126                          12      港        con  ...
#
#   subject_information.gender  subject_information.otherLanguage  \
# 0                     Female                             普通话，英文
# 1                     Female                             普通话，英文
# 2                     Female                             普通话，英文
# 3                     Female                             普通话，英文
# 4                     Female                             普通话，英文
#
#   subject_information.problems  subject_information.prolific_ID  \
# 0                            无         66d0e03800acfdbc181f1450
# 1                            无         66d0e03800acfdbc181f1450
# 2                            无         66d0e03800acfdbc181f1450
# 3                            无         66d0e03800acfdbc181f1450
# 4                            无         66d0e03800acfdbc181f1450
#
#    system.Browser  system.OS  system.screenH system.screenW  time_in_minutes  \
# 0          Chrome        Mac             900           1440         4.313183
# 1          Chrome        Mac             900           1440         4.313183
# 2          Chrome        Mac             900           1440         4.313183
# 3          Chrome        Mac             900           1440         4.313183
# 4          Chrome        Mac             900           1440         4.313183
#
#   error
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 29 columns]

# %%
df['workerid'].value_counts()
# Out:
# workerid
# 19    180
# 33    180
# 20    180
# 13    180
# 27    180
# 34    180
# 18    180
# 26    180
# 29    180
# 31    180
# 21    180
# 28    180
# 22    180
# 25    180
# 23    180
# 17    180
# 15    180
# 30    180
# 14    180
# 24    180
# Name: count, dtype: int64

# %%
# Step 1: Get all columns that start with 'subject_information.'
info_cols = [col for col in df.columns if col.startswith('subject_information.')]
keywords = ['comments', 'problems', 'assess','gender']
info_cols = [col for col in info_cols if not any(k in col for k in keywords)]

# Step 2: Get unique worker IDs
subject_ids = df['workerid'].unique()

# Step 3: Loop over each subject and print their info
for workerid in subject_ids:
    df_subj = df[df['workerid'] == workerid]
    print(f'----- workerid: {workerid} -----')
    for col in info_cols:
        unique_val = df_subj[col].unique()
        print(f'{col}: {unique_val}')
# Out:
# ----- workerid: 19 -----
# subject_information.age: [25]
# subject_information.chinese_country_years: [9]
# subject_information.chinese_family_years: [25]
# subject_information.chinese_school_work_years_spoken: [9]
# subject_information.chinese_school_work_years_written: [9]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通话，英文']
# subject_information.prolific_ID: ['66d0e03800acfdbc181f1450']
# ----- workerid: 33 -----
# subject_information.age: [32]
# subject_information.chinese_country_years: [19]
# subject_information.chinese_family_years: [32]
# subject_information.chinese_school_work_years_spoken: [18]
# subject_information.chinese_school_work_years_written: [18]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通话，粤语，英语']
# subject_information.prolific_ID: ['6595d5e0e40533319c0188c2']
# ----- workerid: 14 -----
# subject_information.age: [30]
# subject_information.chinese_country_years: [0]
# subject_information.chinese_family_years: [0]
# subject_information.chinese_school_work_years_spoken: [0]
# subject_information.chinese_school_work_years_written: [30]
# subject_information.education: [3]
# subject_information.otherLanguage: ['粵語, 普通話, 英文']
# subject_information.prolific_ID: ['65464f3622cb15acd453c658']
# ----- workerid: 30 -----
# subject_information.age: [63]
# subject_information.chinese_country_years: [25]
# subject_information.chinese_family_years: [25]
# subject_information.chinese_school_work_years_spoken: [25]
# subject_information.chinese_school_work_years_written: [25]
# subject_information.education: [4]
# subject_information.otherLanguage: ['普通話']
# subject_information.prolific_ID: ['5e8b32ec2c33ae7f20a0b401']
# ----- workerid: 15 -----
# subject_information.age: [25]
# subject_information.chinese_country_years: [16]
# subject_information.chinese_family_years: [16]
# subject_information.chinese_school_work_years_spoken: [20]
# subject_information.chinese_school_work_years_written: [20]
# subject_information.education: [3]
# subject_information.otherLanguage: ['粤语']
# subject_information.prolific_ID: ['67acf768839ca8641b8645bc']
# ----- workerid: 17 -----
# subject_information.age: [39]
# subject_information.chinese_country_years: [25]
# subject_information.chinese_family_years: [39]
# subject_information.chinese_school_work_years_spoken: [25]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [4]
# subject_information.otherLanguage: ['汉语（普通话），英语，粤语']
# subject_information.prolific_ID: ['64f0a3c4e69e78265f5872e7']
# ----- workerid: 23 -----
# subject_information.age: [42]
# subject_information.chinese_country_years: [19]
# subject_information.chinese_family_years: [19]
# subject_information.chinese_school_work_years_spoken: [12]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通話；英語；荷蘭語']
# subject_information.prolific_ID: ['5e13c06d11999fa232040eb9']
# ----- workerid: 25 -----
# subject_information.age: [40]
# subject_information.chinese_country_years: [28]
# subject_information.chinese_family_years: [40]
# subject_information.chinese_school_work_years_spoken: [28]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通话，英语，日语']
# subject_information.prolific_ID: ['6729195e0d3640e193916a21']
# ----- workerid: 22 -----
# subject_information.age: [30]
# subject_information.chinese_country_years: [25]
# subject_information.chinese_family_years: [30]
# subject_information.chinese_school_work_years_spoken: [30]
# subject_information.chinese_school_work_years_written: [15]
# subject_information.education: [4]
# subject_information.otherLanguage: ['普通话']
# subject_information.prolific_ID: ['67c77e4800b501453f04a4a1 ']
# ----- workerid: 28 -----
# subject_information.age: [42]
# subject_information.chinese_country_years: [33]
# subject_information.chinese_family_years: [42]
# subject_information.chinese_school_work_years_spoken: [18]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [4]
# subject_information.otherLanguage: ['普通话，英文']
# subject_information.prolific_ID: ['5d3522b6eac3d50017df02cb']
# ----- workerid: 21 -----
# subject_information.age: [37]
# subject_information.chinese_country_years: [21]
# subject_information.chinese_family_years: [37]
# subject_information.chinese_school_work_years_spoken: [14]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通话，英文']
# subject_information.prolific_ID: ['65a94e73f78666b2020dbe14']
# ----- workerid: 31 -----
# subject_information.age: [27]
# subject_information.chinese_country_years: [18]
# subject_information.chinese_family_years: [18]
# subject_information.chinese_school_work_years_spoken: [18]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [4]
# subject_information.otherLanguage: ['普通话，英语']
# subject_information.prolific_ID: ['67296a7bde9bf9d7541d058a']
# ----- workerid: 29 -----
# subject_information.age: [28]
# subject_information.chinese_country_years: [18]
# subject_information.chinese_family_years: [28]
# subject_information.chinese_school_work_years_spoken: [18]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [4]
# subject_information.otherLanguage: ['普通话，英语']
# subject_information.prolific_ID: ['66a3ac0c7093275627cde87c']
# ----- workerid: 26 -----
# subject_information.age: [37]
# subject_information.chinese_country_years: [30]
# subject_information.chinese_family_years: [37]
# subject_information.chinese_school_work_years_spoken: [30]
# subject_information.chinese_school_work_years_written: [5]
# subject_information.education: [4]
# subject_information.otherLanguage: ['普通話，英語']
# subject_information.prolific_ID: ['65b82cc0849badb85cdf912b']
# ----- workerid: 18 -----
# subject_information.age: [26]
# subject_information.chinese_country_years: [5]
# subject_information.chinese_family_years: [26]
# subject_information.chinese_school_work_years_spoken: [8]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通话，西班牙语，英语']
# subject_information.prolific_ID: ['5ecd2230b3956a034ebcc660']
# ----- workerid: 34 -----
# subject_information.age: [30]
# subject_information.chinese_country_years: [11]
# subject_information.chinese_family_years: [30]
# subject_information.chinese_school_work_years_spoken: [6]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [2]
# subject_information.otherLanguage: ['普通话，温州话，英文，日语']
# subject_information.prolific_ID: ['66313a1d5b7e48589182d3c9']
# ----- workerid: 27 -----
# subject_information.age: [38]
# subject_information.chinese_country_years: [29]
# subject_information.chinese_family_years: [38]
# subject_information.chinese_school_work_years_spoken: [15]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [-1]
# subject_information.otherLanguage: ['普通話,英语']
# subject_information.prolific_ID: ['5ec59e86c9569f5e8000717b']
# ----- workerid: 13 -----
# subject_information.age: [27]
# subject_information.chinese_country_years: [20]
# subject_information.chinese_family_years: [20]
# subject_information.chinese_school_work_years_spoken: [14]
# subject_information.chinese_school_work_years_written: [1]
# subject_information.education: [4]
# subject_information.otherLanguage: ['普通话 英语']
# subject_information.prolific_ID: ['6640f6595f6d51682bc75ab5@email.prolific.com']
# ----- workerid: 20 -----
# subject_information.age: [36]
# subject_information.chinese_country_years: [22]
# subject_information.chinese_family_years: [36]
# subject_information.chinese_school_work_years_spoken: [22]
# subject_information.chinese_school_work_years_written: [0]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通话 英语']
# subject_information.prolific_ID: ['65a957ec60b511521c781d4c']
# ----- workerid: 24 -----
# subject_information.age: [35]
# subject_information.chinese_country_years: [27]
# subject_information.chinese_family_years: [35]
# subject_information.chinese_school_work_years_spoken: [19]
# subject_information.chinese_school_work_years_written: [1]
# subject_information.education: [3]
# subject_information.otherLanguage: ['普通话，英文']
# subject_information.prolific_ID: ['6652b039261ef03ecb978b4b']

# %%
subjects = df['workerid'].unique().tolist()
remove_set = {14,15}
subjects = [x for x in subjects if x not in remove_set]
n_subjects = len(subjects)

print('Total number of subjects: ', n_subjects)
# Out:
# Total number of subjects:  18

# %%
df.columns
# Out:
# Index(['workerid', 'proliferate.condition', 'correct_answer', 'prime',
#        'probeContent', 'response', 'rt', 'slide_number_in_experiment',
#        'target', 'trial_type', 'catch_trials', 'subject_information.age',
#        'subject_information.assess',
#        'subject_information.chinese_country_years',
#        'subject_information.chinese_family_years',
#        'subject_information.chinese_school_work_years_spoken',
#        'subject_information.chinese_school_work_years_written',
#        'subject_information.comments', 'subject_information.education',
#        'subject_information.gender', 'subject_information.otherLanguage',
#        'subject_information.problems', 'subject_information.prolific_ID',
#        'system.Browser', 'system.OS', 'system.screenH', 'system.screenW',
#        'time_in_minutes', 'error'],
#       dtype='object')

# %%
def compute_accuracy(df):

    ntrials = len(df)
    n_correct_trials = 0
    
    for ii in range(len(df)):

        trial = df.iloc[ii]
        correct_answer = trial['correct_answer']
        response = trial['response']

        if (correct_answer == 1 and response == 'f') or (correct_answer == 2 and response == 'j'):

            n_correct_trials += 1

    accuracy_percent = n_correct_trials / ntrials

    return accuracy_percent

# %%
def compute_rt(df, trial_type):

    df_trial_type = df[df['trial_type'] == trial_type]
    #df_trial_type = df_trial_type[df_trial_type['correct_answer'] == 1]


    rt = df_trial_type['rt']

    rt = rt - (300 + 300 + 300 + 300)

    assert(rt > 0).all(), "Some RTs are not greater than 0"

    return(rt.mean())

# %%
results = []

for subj in range(n_subjects):
    workerid = subjects[subj]
    df_workerid = df[df['workerid'] == workerid]

    overall_accuracy = compute_accuracy(df_workerid)

    trial_types = df_workerid['trial_type'].unique()
    for trial_type in trial_types:
        mean_rt = compute_rt(df_workerid, trial_type)

        # Append a dictionary of results for this subject and trial type
        results.append({
            'workerid': workerid,
            'accuracy': overall_accuracy,
            'trial_type': trial_type,
            'mean_rt': mean_rt
        })

# Convert the list of dictionaries into a DataFrame
results_df = pd.DataFrame(results)

# %%
print(results_df)
# Out:
#     workerid  accuracy trial_type      mean_rt
# 0         19  0.994444        con   805.782609
# 1         19  0.994444    sem-sem   676.904762
# 2         19  0.994444   phon-sem   674.440000
# 3         19  0.994444  phon-phon   748.478261
# 4         33  1.000000   phon-sem  1134.480000
# ..       ...       ...        ...          ...
# 67        20  0.955556        con   977.000000
# 68        24  0.994444    sem-sem   539.608696
# 69        24  0.994444   phon-sem   644.500000
# 70        24  0.994444  phon-phon   558.285714
# 71        24  0.994444        con   538.407407
#
# [72 rows x 4 columns]

# %%
trial_types = df['trial_type'].unique()

for tt in range(len(trial_types)):

    this_type = trial_types[tt]

    df_type = results_df[results_df['trial_type'] == this_type]

    mean_rt = df_type['mean_rt'].mean()

    print(this_type, mean_rt)
# Out:
# con 821.6467025940395
# sem-sem 786.6876058835754
# phon-sem 827.4852086895642
# phon-phon 954.1025860466403
